# %% [markdown]
# # Model training
# Use this notebook to train and export your model to `../model/house_model.pkl`.

# %%
import pandas as pd
df = pd.read_csv('../data/cleaned_house_data.csv')
df.head()
